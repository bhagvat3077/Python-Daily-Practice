# %%
def my_fun(name,/):
    print("Hello",name)
my_fun("Amit")
# Out:
# Hello Amit

# %%
def my_fun(*,name):
    print("Hello",name)
my_fun(name = "Amit")
# Out:
# Hello Amit

# %%
# function define in onther function defination
def myfunc():
    x = 300
    def myinner
