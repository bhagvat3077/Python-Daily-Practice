# %%
s={"apple","banana","cherry","banana","apple"}
print(s)
print(type(s))
# Out:
# {'apple', 'cherry', 'banana'}
# <class 'set'>

# %%
# To convert any data type in Set()
s={"apple","banana","cherry","banana","apple"}
