# %%
#Example of marks using ifelse

a=int (input("Enter your marks:- "))
if a>=90:
    print("Grade:A")
elif a>=80:
    print("Grade:B")
elif a>=70:
    print("Grade:c")
else:
    print("Grade:B")
# Out:
# Grade:B

# %%
# Password check
a=1010
b=int(input("Enter your password:- "))
if a==b:
    print("{} password is correct ".format(b))
else:
    print("{} Invalid Password ".format(b))
# Out:
# 1010 password is correct

# %%
# Number check
a=int(input("enter number: "))
if a>0:
    print("Number {} is positive ".format(a))
elif a<0:
    print("Number {} is negative ".format(a))
else :
    print("Number {} is netural ".format(a))
# Out:
# Number 0 is netural

# %%
#WAP user to enter distan in km
# if dist is more than 10km : print charge is 100rs
# if dist is more than 7 to 10 km : print charge is 70rs
# if dist is more than 4 to 7km : print charge is 40rs
# otherwise print charge is 30rs

d=int(input("enter a distance:- "))
c1=100
c2=70
c3=40
c4=30
if d>10:
    print("The Distance {} KM so charges is {} rupees.".format(d,c1))
elif d<10 :
    if d>7:
        print("The Distance {} KM so charges is {} rupees.".format(d,c2))
elif d<7:
    if d>4:
        print("The Distance {} KM so charges is {} rupees.".format(d,c3))
else:
    print("The Distance {} KM so charges is {} rupees.".format(d,c4))
# Out:
# The Distance 8 KM so charges is 70 rupees.

# %%
#WAP ask the user enter salary
#if salary>10 lks:
#ask user to enter the user tax % :10%
#print the amount of tax paid (salary*tax-year)/100

#if salarybetween 7 to 10 lks:
#ask user to enter the user tax % :5%
#print the amount of tax paid

#if salarybetween 4 to 7 lks:
#ask user to enter the user tax % :2.5%
#print the amount of tax paid

#otherwise no tax requried

s1=float(input("Enter your salary:- "))
if s1>1000000:
    t1=(s1*10)/100
    print("Your salary is {} so you need paid tax amount of {}".format(s1,t1))
elif 700000 < s1 <1000000:
        t1=(s1*5)/100
        print("Your salary is {} so you need paid tax amount of {}".format(s1,t1))
elif 400000 < s1 < 700000:
        t1=(s1*2.5)/100
        print("Your salary is {} so you need paid tax amount of {}".format(s1,t1))  
else:
    print("Your salary is {} so No tax requried ".format(s1))
# Out:
# Your salary is 1200000.0 so you need paid tax amount of 120000.0

# %%
# Check number is zero, postive or negative
num=int(input("Enter a number:- "))
if num>=0:
    if num==0:
        print(num, "Number is Zero")
    else:
        print(num, "Number is Positive")
else:
    print(num, "Number is Negative")
# Out:
# 0 Number is Zero

# %%
#  1. WAP ask user a no. and print it is even or odd
num=int(input("Enter a number:- "))
if num%2==0:
    print(num, "Number is Even")
else:
    print(num, "Number is odd")
# Out:
# 13 Number is odd

# %%
# WAP
#  Take a number and print:
    # Its square root if number is positive
    # "Invalid number" if negative
a=float(input("Enter a number:- "))
if a>=0:
    sqr=a**0.5
    print("Square Root of {} is equal to {}".format(a,sqr))
else:
    print("{} is Invalid Number".format(a))
# Out:
# Square Root of 25.0 is equal to 5.0

# %%
# Nested if: Check Voting Eligibility Conditions:
# Age ≥ 18, else citizen = No
# if above 40 : aged, else adult
age=int(input("Enter a age:- "))
if age<=18:
    print("Your age is {} So your are Adult".format(age))
else:
    print("Your age is {} So you are aged".format(age))
# Out:
# Your age is 17 So your are Adult

# %%
#Nested if and if-elif-else : Largest of Three Numbers
a=int(input("Enter a first number:-"))
b=int(input("Enter a first number:-"))
c=int(input("Enter a first number:-"))

if a>b:
    if a>c:
        print("Largest number is ",a)
    else:
        print("Largest number is ",c)   
else:
    if b>c:
        print("Largest number is ",b)   
    else:
        print("Largest number is ",c)
# Out:
# Largest number is  300

# %%
# WAP for ATM function
#Withdraw,deposite,main balance
print("Welcom to our Branch")
print("1. Deposit")
print("2. Withdraw")
print("3. Check Balance")

choice = int(input("Enter your choice (1/2/3): "))

if choice == 1:
    amount = int(input("Enter amount to deposit: "))
    balance = balance + amount
    print("Deposit successful")
    print("Current Balance:", balance)

elif choice == 2:
    amount = int(input("Enter amount to withdraw: "))
    if amount <= balance:
        balance = balance - amount
        print("Please collect your cash")
        print("Current Balance:", balance)
    else:
        print("Insufficient balance")

elif choice == 3:
    print("Your Current Balance:", balance)

else:
    print("Invalid choice")
