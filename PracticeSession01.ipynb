# %%
print(10+5*2)
print((10+5)*2)
print(20-4**2) #20-4=16 then 16 ka sqr root-4=ans is 4
print(100//5*2)
print(18%5+2)
print(2**3**2)
print(4*2*3)
print(16//2**2)
print(9+6*2**2)
print(8-2**2*2)
# Out:
# 20
# 30
# 4
# 40
# 5
# 512
# 24
# 4
# 33
# 0

# %%
print(10>5 and 5>2)
print(10>5 and 5<2)
print(not 10>5)
print(True or False and false)
print(5<10<20)
x=5
x+=3*2
print(x)
x=10
x*=2+3
print(x)
# Out:
# True
# False
# False
# True
# True
# 11
# 50

# %%
x=5
x=x==5
print(x)

x=2
x**2+1
print(x)

x=1
x+=x==1
print(x)
# Out:
# True
# 2
# 2

# %%
print(5 and 0 or 8)
print(0 or 5 and 8)
print(True==False or True)
print(False ==False and False)
print(not True==False)
# Out:
# 8
# 8
# True
# False
# True

# %%
#1WAP to check in given char is present in string 

# for i in "hello":
#     if i=="e":
#         print(i,"is present in hello")

s=input("Enter a string: ")
ch=input("Which character need to b search")
if ch in s:
    print("The character {} present in string {}".format(ch,s))
# Out:
# The character e present in hello

# %%
#2 WAP to check if a given number is in predefined list of prime numbers
a=int(input("Enter a number"))
list=2,3,5,7,11
if list==a:
    print(a, "is prime number")
else:
    print(a,"is Not prime number" )
# Out:
# 7 Not prime number

# %%
# 3 WAP to check if a user chosen username is already in list of esisting usernames
un=input("Enter a username")
list=("alice","bob","john123")
if un in list:
    print(un,"username already taken")
else:
    print(un)
# Out:
# john123 username already taken

# %%
#4 WAP to check if a world is part of given sentence(input both and sentence)
a=input("Enter a word")
s=("The sun rise in the east")
if a in s:
    print(a,"is present in the senteance.",)
# Out:
# sun is present in the senteance

# %%
#5 WAP to check if an iteam is not present in a shopping cart list and add if it is missing
it=input("Which itam we want:")
list=["bread","eggs"]
if it in list:
    print(it)
else:
    print(it,"Not found")  
print("Not found so please add ",it,"in list")
list.append(it)
print(it,"is added")
print(list)
# Out:
# milk Not found
# Not found so please add  milk in list
# milk is added
# ['bread', 'eggs', 'milk']

# %%
#6 WAP to check if two variable refer to the same object in memory
a=[1,2]
b=a
if a is b:
    print("a and b refer a same object")
else:
    print("a and b NOT refer a same object")
# Out:
# a and b refer a same object

# %%
#7 WAP to check if two list  refer to the same object and different objects
list1=[1,2,3]
list2=[1,2,3]
if list1 is list2:
    print("list1 and list2 refer a same object")
else:
    print("list1 and list2 refer a same object")
# Out:
# list1 and list2 refer a same object

# %%
#8 WAP to check if variable is none
variable = None

# Check if variable is None
if variable is None:
    print("The variable is None")
else:
    print("The variable is not None")
# Out:
# The variable is None

# %%
#9 WAP to check if variable is none - input is hello
variable = "Hello"

# Check if variable is None
if variable is None:
    print("The variable is None")
else:
    print("The variable is not None")
# Out:
# The variable is not None

# %%
#10 WAP to compare two string and check if they are same object or just eqal in value
str1 = "apple"

str2 = ["a", "p", "p", "l", "e"]

# Check if they are the same object
if str1 is str2:
    print("str1 and str2 are the same value")
else:
    print("str1 and str2 are the same object")
# Out:
# str1 and str2 are the same object
