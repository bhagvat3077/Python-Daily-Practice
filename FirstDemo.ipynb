# %%
print('He hello,"What are doing" ')
# Out:
# He hello,"What are doing"

# %%
print("hello@%$&*77TThev")
# Out:
# hello@%$&*77TThev

# %%
num1=5
num2=10
add=num1+num2
print("Addition: ",add)
# Out:
# Addition:  15

# %%
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>
