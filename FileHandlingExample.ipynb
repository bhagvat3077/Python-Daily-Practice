# %%
file_location = "C:\\Users\\hp\\OneDrive\\Desktop\\Bhagvat\\Python 2026\\example.txt"
file_name = "example"
extension = ".txt"

file = open(file_location)
file.read()
# Out:
# 'Hello World\nI like to play Cricket\nIndia is my country!!\nWe are playing volleball.\nToday I got 50 Rupees.'

# %%
file = open(file_location)
content = file.read()
print(content)
file.close()
# Out:
# Hello World
# I like to play Cricket
# India is my country!!
# We are playing volleball.
# Today I got 50 Rupees.

# %%
with open('example.txt','r') as file:
    print(file.read())
# Out:
# Hello World
# I like to play Cricket
# India is my country!!
# We are playing volleball.
# Today I got 50 Rupees.

# %%
with open('example.txt') as f:
    print(f.read(10))
    print(f.readline())
    print(f.readline())
# Out:
# Hello Worl
# d
#
# I like to play Cricket
