# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.__age = age  # self>__Person__age = age

p1 = Person("Ram",30)

print(p1.name)
#print(p1.age)  # ist given error like 'Person' object has no attribute 'age'
## How this is print

print(p1._Person__age)  # we can acces the age
# Out:
# Ram
# 30
