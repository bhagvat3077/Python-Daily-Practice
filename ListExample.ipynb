# %%
li=[11,22,33]
print(li,type(li))
print(max(li))
print(min(li))
print(sum(li))
# Out:
# [11, 22, 33] <class 'list'>
# 33
# 11
# 66

# %%
li=["Hello","How","are","you"]
print(li,type(li))
# Out:
# ['Hello', 'How', 'are', 'you'] <class 'list'>

# %%
#retrive the "ball" using index:
list=[1,2,3,["app"]]
